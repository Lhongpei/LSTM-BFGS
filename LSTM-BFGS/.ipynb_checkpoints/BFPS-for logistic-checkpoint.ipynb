# %%
import torch
import torchmin.bfgs as bfs
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import torchmin.benchmarks as bm

# %%
batchsize=128
DIM=10

# %%
USE_CUDA=False
if torch.cuda.is_available():
    USE_CUDA=True
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
USE_CUDA
# Out:
# True

# %% [markdown]
# ## Define objective function
# Considering linear search is useful, we define 2 kinds of loss funtion.<br>
# - loss for each samples in this batch
# - mean loss for this batch

# %%
# 定义一个二次函数作为例子
def f(W,Y,x):
    """quadratic function : f(\theta) = \|W\theta - y\|_2^2"""
    if USE_CUDA:
        W = W.cuda()
        Y = Y.cuda()
        x = x.cuda()

    return ((torch.matmul(W,x.unsqueeze(-1)).squeeze()-Y)**2).sum(dim=1)

# %% [markdown]
# ## BFGS update iteration

# %%
class BFGS:
    def __init__(self,batchsize,DIM,device):
        self.I = torch.eye(DIM, device=x.device, dtype=x.dtype,requires_grad=True).unsqueeze(0).expand(batchsize, -1, -1)
        self.H = self.I.clone()
    def H_BFDS_update(self,s,y):
        st=s.unsqueeze(1)
        s=s.unsqueeze(2)
        yt=y.unsqueeze(1)
        y=y.unsqueeze(2)
        sy=torch.matmul(s,yt)
        ss=torch.matmul(s,st)
        yst=torch.matmul(y,st)
        yts=torch.matmul(yt,s)
        #print(yts.min())
        yHy=torch.matmul(torch.matmul(yt,self.H),y)
        self.H=self.H-(torch.matmul(sy,self.H)+torch.matmul(self.H,yst))/yts+(yHy/yts+1)*ss/yts
        #print(self.H)

# %% [markdown]
# ## Linear search (Strong Wolfe)

# %%
import torch

def strong_wolfe(W,Y,batchsize,f, x, step_dir, loss, grad, device, c1=1e-4, c2=0.9, max_iter=10):
    """
    Strong Wolfe Line Search
    Args:
    - f: Function to be optimized
    - x: Current point
    - step_dir: Search direction
    - loss: Loss at current point
    - grad: Gradient at current point
    - c1: Armijo condition parameter
    - c2: Curvature condition parameter
    - max_iter: Maximum number of iterations

    Returns:
    - step_size: Calculated step size
    """

    # Initialize step size
    step_size = torch.ones((batchsize,1),device=device)
    grad=grad.unsqueeze(1)
    #print(step_dir.shape)
    #step_dir=step_dir.unsqueeze(2)
    for i in range(max_iter):
        new_loss = f(W,Y,x + step_size * step_dir.squeeze())
        
        armijo_condition = new_loss > loss + c1 * step_size.squeeze() * torch.matmul(grad, step_dir).squeeze()
        #print(armijo_condition.shape)
        new_grad = torch.autograd.grad(new_loss.mean(), x)[0]
        curvature_condition = torch.matmul(new_grad.unsqueeze(1), step_dir).squeeze() < c2 * torch.matmul(grad, step_dir).squeeze()

        if torch.sum(armijo_condition)==0 and torch.sum(curvature_condition)==0:
            return step_size
        elif torch.sum(armijo_condition)>0:
            step_size[armijo_condition] *= 0.5  # Reduce step size by half
        elif torch.sum(curvature_condition)>0:
            step_size[curvature_condition] *= 2.0  # Double step size

    return step_size  # Return step size after maximum iterations reached

# Usage Example:
# Define your function f, starting point x, loss, gradient, and search direction
# Then call strong_wolfe function to get the step size
# step_size = strong_wolfe(f, x, step_dir, loss, grad)

# %% [markdown]
# ## BFGS

# %%
W = torch.randn((batchsize, DIM, DIM), device=device) # represents IID
Y = torch.randn((batchsize,DIM),device=device)
x = torch.zeros((batchsize,DIM),device=device,requires_grad=True)

steps=200
B=BFGS(batchsize,DIM,device)
mem_loss=[]
loss=f(W,Y,x)
acc=1e-6
mem_loss.append(loss.mean())
g=torch.autograd.grad(loss.mean(),x)[0]
d=-torch.matmul(B.H,g.unsqueeze(2))
k=0
#print(loss)
for i in range(steps):
    g_pre=g
    alpha=strong_wolfe(W,Y,batchsize,f, x, d, loss, g, c1=1e-4, c2=0.9, max_iter=10,device=device)
    update=alpha*(d.squeeze())
    x=x+update
    loss=f(W,Y,x)
    mem_loss.append(loss.mean())
    g=torch.autograd.grad(loss.mean(),x)[0]
    #print(torch.norm(g,dim=1).mean())
    if(sum(torch.norm(g,dim=1)<acc)>0):
        break
    d=-torch.matmul(B.H,g.unsqueeze(2))
    #print(B.H)
    B.H_BFDS_update(update,g-g_pre)
    k+=1
    
print(k)    
plt.plot([i.cpu().detach().numpy() for i in mem_loss])
# Out:
# 41

# %% [markdown]
# ## LSTM define

# %%
class LSTM_motify(torch.nn.Module):
    """LSTM修正器
       LSTM optimizer"""
    
    def __init__(self,input_size,output_size, hidden_size, num_stacks, batchsize,p  = 10 ,preprocess = True, output_scale = 1):
        super(LSTM_motify,self).__init__()
        self.preprocess_flag = preprocess
        self.input_flag = 2
        if preprocess != True:
             self.input_flag = 1
        self.p = p
        self.output_scale = output_scale 
        self.lstm = torch.nn.LSTM(input_size*self.input_flag, hidden_size, num_stacks)
        self.Linear = torch.nn.Linear(hidden_size,output_size) #1-> output_size
        print(self.preprocess_flag)
        
    def LogAndSign_Preprocess_Gradient(self,gradients):
        """
        Args:
          gradients: `Tensor` of gradients with shape `[d_1, ..., d_n]`.
          p       : `p` > 0 is a parameter controlling how small gradients are disregarded 
        Returns:
          `Tensor` with shape `[d_1, ..., d_n-1, 2 * d_n]`. The first `d_n` elements
          along the nth dimension correspond to the `log output` \in [-1,1] and the remaining
          `d_n` elements to the `sign output`.
        """
        p  = self.p
        log = torch.log(torch.abs(gradients))
        clamp_log = torch.clamp(log/p , min = -1.0,max = 1.0)
        clamp_sign = torch.clamp(torch.exp(torch.tensor(p))*gradients, min = -1.0, max =1.0)
        return torch.cat((clamp_log,clamp_sign),dim = -1) #在gradients的最后一维input_dims拼接
    
    def Output_motification_And_motify_LSTM_Hidden_State(self, input_gradients, prev_state):
        """LSTM的核心操作  core operation
        coordinate-wise LSTM """
        if prev_state is None: #init_state
            prev_state = (torch.zeros(Layers,batchsize,Hidden_nums),
                            torch.zeros(Layers,batchsize,Hidden_nums))
            if USE_CUDA :
                 prev_state = (torch.zeros(Layers,batchsize,Hidden_nums).cuda(),
                            torch.zeros(Layers,batchsize,Hidden_nums).cuda())
         			
        motify , next_state = self.lstm(input_gradients, prev_state)
        motify = self.Linear(motify) * self.output_scale # transform the LSTM output to the target output dim 
        return motify, next_state
    
    def forward(self,input_data, prev_state):
        if USE_CUDA:
            input_data = input_data.cuda()
        #pytorch requires the `torch.nn.lstm`'s input as（1，batchsize,input_dim）
        # original gradient.size()=torch.size[5] ->[1,1,5]
        # gradients = move_gradients.unsqueeze(0)
        # moves = move.unsqueeze(0)
        # combined = torch.cat((moves, gradients), dim=0)
        if self.preprocess_flag == True:
            #print(input_data.shape)
            input_data = self.LogAndSign_Preprocess_Gradient(input_data)
        motify , next_state = self.Output_motification_And_motify_LSTM_Hidden_State(input_data , prev_state)
        # Squeeze to make it a single batch again.[1,1,5]->[5]
        motify = motify.squeeze().squeeze()
       
        return motify , next_state

# %%
Layers = 2
Hidden_nums = 20
Input_DIM = DIM*2
Output_DIM = DIM**2
output_scale_value=1

#######   构造一个优化器  #######
#######  construct a optimizer  #######
LSTM_motify = LSTM_motify(Input_DIM, Output_DIM, Hidden_nums ,Layers , batchsize=batchsize,\
                preprocess=False,output_scale=output_scale_value)
print(LSTM_motify)

if USE_CUDA:
    LSTM_optimizer = LSTM_motify.cuda()
# Out:
# False
# LSTM_motify(
#   (lstm): LSTM(20, 20, num_layers=2)
#   (Linear): Linear(in_features=20, out_features=100, bias=True)
# )

# %% [markdown]
# ## LSTM pre-train vs BFGS

# %%
import time

# %%
def record(loss,standard='mean',num=0):
    if standard=='mean':
        return loss.mean()
    else:
        return loss[num]

# %%
def LSTM_iter(W,Y,x,batchsize,DIM,device,standard='mean',rec_num=0,step=50,acc=1e-6,plot=False):    
    start_time=time.time()
    state=None#初始化LSTM hidden state
    H=torch.eye(DIM, device=x.device, dtype=x.dtype,requires_grad=True).unsqueeze(0).expand(batchsize, -1, -1)
    mem_loss=[]#初始化loss的list
    loss=f(W,Y,x)#每个case的loss
    global_loss_graph = 0#记录每个迭代的总loss 用于后向传播
    lossmean=loss.mean()#总loss的平均值

    global_loss_graph+=lossmean
    mem_loss.append(loss[rec_num])

    lossmean.backward(retain_graph=True)
    g = x.grad.clone()#g detach掉
    d=-torch.matmul(H,g.unsqueeze(2))
    k=0
    #print(loss)
    for i in range(steps):
        g_pre=g.clone()# 保存g作为上一次的g，此时g_pre不在计算图中
        alpha=strong_wolfe(W,Y,batchsize,f, x, d, loss, g, c1=1e-4, c2=0.9, max_iter=10,device=device)
        alpha.detach_()
        update=alpha*d.squeeze()
        # update=d.squeeze()
        x=x+update
        x.retain_grad()
        loss=f(W,Y,x)
        lossmean=loss.mean()
        global_loss_graph+=lossmean
        mem_loss.append(loss[rec_num])
        #print(mem_loss[0])
        lossmean.backward(retain_graph=True)
        #print([i.grad for i in LSTM_motify.parameters()])
        #print(g)
        g = x.grad.clone()
        #print(torch.norm(g,dim=1).mean())
        if(sum(torch.norm(g,dim=1)<acc)>0):
            break
        #print(B.H)
        input_vec=torch.cat((g,update),dim=1).unsqueeze(0)
        #print(input_vec.is_leaf)
        motify,state=LSTM_motify(input_vec,state)
        deltaH=motify.reshape((batchsize, DIM, DIM))
        H = H.clone().detach() + deltaH*deltaH.transpose(1, 2)
        H.retain_grad()
        d=-torch.matmul(H,g.unsqueeze(2))
        k+=1
    if plot:
        plt.plot([i.cpu().detach().numpy() for i in mem_loss],label='LSTM')
        end_time = time.time()
        LSTM_time = end_time - start_time
    return mem_loss,global_loss_graph,LSTM_time

# %%
def BFGS_iter(W,Y,x,batchsize,DIM,device,standard='mean',rec_num=0,step=100,acc=1e-6,plot=False):
    start_time=time.time()
    B=BFGS(batchsize,DIM,device)
    mem_loss=[]
    loss=f(W,Y,x)
    acc=1e-6
    global_loss=0
    lossmean=loss.mean()
    global_loss+=lossmean
    mem_loss.append(loss[rec_num])
    g=torch.autograd.grad(loss.mean(),x)[0]
    d=-torch.matmul(B.H,g.unsqueeze(2))
    k=0
    #print(loss)
    for i in range(steps):
        g_pre=g
        alpha=strong_wolfe(W,Y,batchsize,f, x, d, loss, g, c1=1e-4, c2=0.9, max_iter=10,device=device)
        update=alpha*(d.squeeze())
        x=x+update
        loss=f(W,Y,x)
        lossmean=loss.mean()
        global_loss+=lossmean
        mem_loss.append(loss[rec_num])
        g=torch.autograd.grad(lossmean,x)[0]
        #print(torch.norm(g,dim=1).mean())
        if(sum(torch.norm(g,dim=1)<acc)>0):
            break
        d=-torch.matmul(B.H,g.unsqueeze(2))
        #print(B.H)
        B.H_BFDS_update(update,g-g_pre)
        k+=1

    end_time = time.time()
    BFGS_time = end_time - start_time
    if plot:
        plt.plot([i.cpu().detach().numpy() for i in mem_loss],label='BFGS')  
    return mem_loss,global_loss,BFGS_time

# %%
def gradient_iter(W,Y,x,batchsize,DIM,device,standard='mean',rec_num=0,step=50,acc=1e-6,plot=False):    
    start_time=time.time()
    mem_loss=[]#初始化loss的list
    loss=f(W,Y,x)#每个case的loss
    global_loss_graph = 0#记录每个迭代的总loss 用于后向传播
    lossmean=loss.mean()#总loss的平均值

    global_loss_graph+=lossmean
    mem_loss.append(loss[rec_num])

    lossmean.backward(retain_graph=True)
    g = x.grad
    k=0
    #print(loss)
    for i in range(steps):
        # update=d.squeeze()
        x=x-g
        x.retain_grad()
        loss=f(W,Y,x)
        lossmean=loss.mean()
        global_loss_graph+=lossmean
        mem_loss.append(loss[rec_num])
        #print(mem_loss[0])
        lossmean.backward(retain_graph=True)
        #print([i.grad for i in LSTM_motify.parameters()])
        #print(g)
        g = x.grad
        #print(torch.norm(g,dim=1).mean())
        if(sum(torch.norm(g,dim=1)<acc)>0):
            break
        #print(B.H)
        #print(input_vec.is_leaf)
        k+=1
    if plot:
        plt.plot([i.cpu().detach().numpy() for i in mem_loss],label='Gradient')
        end_time = time.time()
        LSTM_time = end_time - start_time
    return mem_loss,global_loss_graph,LSTM_time

# %%
batchsize=128
W = torch.randn((batchsize, DIM, DIM), device=device) # represents IID
Y = torch.randn((batchsize,DIM),device=device)
x = torch.zeros((batchsize,DIM),device=device,requires_grad=True)
bfgs_loss,bfgs_tot_loss,bfgs_time=BFGS_iter(W,Y,x,batchsize,DIM,device,rec_num=0,standard='mean',acc=1e-6,plot=True)
lstm_loss,lstm_tot_loss,lstm_time=LSTM_iter(W,Y,x,batchsize,DIM,device,rec_num=0,standard='mean',acc=1e-6,plot=True)
grad_loss,grad_tot_loss,grad_time=gradient_iter(W,Y,x,batchsize,DIM,device,rec_num=0,standard='mean',acc=1e-6,plot=True)
plt.legend()

# %% [markdown]
# ## Train LSTM

# %%
def RUN(W,Y,x,batchsize,DIM,steps=40,eps=10,reset=True):
    if reset:
        x = torch.zeros((batchsize,DIM),device=device,requires_grad=True)
    x.requires_grad=True
    state=None#初始化LSTM hidden state
    H=torch.eye(DIM, device=x.device, dtype=x.dtype,requires_grad=True).unsqueeze(0).expand(batchsize, -1, -1)
    mem_loss=[]#初始化loss的list
    loss=f(W,Y,x)#每个case的loss
    global_loss_graph = 0#记录每个迭代的总loss 用于后向传播
    lossmean=loss.mean()#总loss的平均值

    global_loss_graph+=lossmean
    mem_loss.append(lossmean.clone().detach())
    lossmean.backward(retain_graph=True)
    g = x.grad.clone()#g detach掉
    d=-torch.matmul(H,g.unsqueeze(2))
    k=0
    #print(loss)
    for i in range(steps):
        g_pre=g.clone()# 保存g作为上一次的g，此时g_pre不在计算图中
        alpha=strong_wolfe(W,Y,batchsize,f, x, d, loss, g, c1=1e-4, c2=0.9, max_iter=10,device=device)
        alpha.detach_()
        update=alpha*d.squeeze()
        # update=d.squeeze()
        x=x+update
        x.retain_grad()
        loss=f(W,Y,x)
        lossmean=loss.mean()
        global_loss_graph+=lossmean
        mem_loss.append(lossmean.clone().detach())
        #print(mem_loss[0])
        lossmean.backward(retain_graph=True)
        #print([i.grad for i in LSTM_motify.parameters()])
        #print(g)
        g = x.grad.clone()
        #print(torch.norm(g,dim=1).mean())
        if(sum(torch.norm(g,dim=1)<acc)>0):
            break
        #print(B.H)
        input_vec=torch.cat((g,update),dim=1).unsqueeze(0)
        #print(input_vec.is_leaf)
        motify,state=LSTM_motify(input_vec,state)
        deltaH=motify.reshape((batchsize, DIM, DIM))
        H = H.clone().detach() + deltaH*deltaH.transpose(1, 2)
        H.retain_grad()
        d=-torch.matmul(H,g.unsqueeze(2))
        k+=1
    # plt.plot([i.cpu().detach().numpy() for i in mem_loss],label='LSTM_before_train')

    return mem_loss,global_loss_graph,x

# %%
def global_training(Global_Train_Steps,substeps,eachsteps,motifier):
    global_loss_list = []    
    adam_global_optimizer = torch.optim.Adam(motifier.parameters(),lr = 0.0001)
    W = torch.randn((batchsize, DIM, DIM), device=device) # represents IID
    Y = torch.randn((batchsize,DIM),device=device)
    x = torch.zeros((batchsize,DIM),device=device,requires_grad=True)
    _,global_loss_1,x = RUN(W,Y,x,batchsize,DIM,steps=eachsteps)
    print(global_loss_1)
    for i in tqdm(range(Global_Train_Steps)):
        W = torch.randn((batchsize, DIM, DIM), device=device) # represents IID
        Y = torch.randn((batchsize,DIM),device=device)
        subiterloss=0
        for j in range(substeps):
            resetflag=(j==0)
            _,global_loss,x = RUN(W,Y,x.clone().detach(),batchsize,DIM,steps=eachsteps,reset=resetflag)
            subiterloss+=global_loss
            adam_global_optimizer.zero_grad()
            global_loss.backward() #每次都是优化这个固定的图，不可以释放动态图的缓存
            #print('xxx',[z.shape for z in motifier.parameters()  ])
            adam_global_optimizer.step()
        #print('iteration:{},mean_loss:{}'.format(i,subiterloss))
        #print('xxx',[(z.grad,z.requires_grad) for z in motifier.parameters()  ])
        global_loss_list.append(global_loss.detach_())
        
    print(global_loss)
    return global_loss_list

# %%
global_training(1000,3,100,LSTM_motify)
# Out:
# tensor(110.5633, device='cuda:0', grad_fn=<AddBackward0>)
# 100%|████████████████████████████████████████████████████████████████████████████| 1000/1000 [1:37:08<00:00,  5.83s/it]
# tensor(0.9026, device='cuda:0')
# [tensor(9.4084, device='cuda:0'),
#  tensor(1.2223, device='cuda:0'),
#  tensor(44.7800, device='cuda:0'),
#  tensor(1.5835, device='cuda:0'),
#  tensor(0.7881, device='cuda:0'),
#  tensor(1.2544, device='cuda:0'),
#  tensor(5.4268, device='cuda:0'),
#  tensor(8.5266, device='cuda:0'),
#  tensor(17.1612, device='cuda:0'),
#  tensor(1.0909, device='cuda:0'),
#  tensor(39.5229, device='cuda:0'),
#  tensor(0.9476, device='cuda:0'),
#  tensor(1.0331, device='cuda:0'),
#  tensor(0.8354, device='cuda:0'),
#  tensor(1.0186, device='cuda:0'),
#  tensor(12.8541, device='cuda:0'),
#  tensor(0.9374, device='cuda:0'),
#  tensor(20.5736, device='cuda:0'),
#  tensor(1.0286, device='cuda:0'),
#  tensor(1.0693, device='cuda:0'),
#  tensor(21.8651, device='cuda:0'),
#  tensor(23.4231, device='cuda:0'),
#  tensor(1.0879, device='cuda:0'),
#  tensor(3.1527, device='cuda:0'),
#  tensor(0.8894, device='cuda:0'),
#  tensor(1.0486, device='cuda:0'),
#  tensor(0.8051, device='cuda:0'),
#  tensor(1.1792, device='cuda:0'),
#  tensor(1.1504, device='cuda:0'),
#  tensor(10.1741, device='cuda:0'),
#  tensor(22.2916, device='cuda:0'),
#  tensor(0.9111, device='cuda:0'),
#  tensor(0.6937, device='cuda:0'),
#  tensor(0.8862, device='cuda:0'),
#  tensor(1.1411, device='cuda:0'),
#  tensor(16.1684, device='cuda:0'),
#  tensor(1.0397, device='cuda:0'),
#  tensor(1.0150, device='cuda:0'),
#  tensor(11.1890, device='cuda:0'),
#  tensor(1.1448, device='cuda:0'),
#  tensor(8.0356, device='cuda:0'),
#  tensor(27.4615, device='cuda:0'),
#  tensor(1.1944, device='cuda:0'),
#  tensor(18.8028, device='cuda:0'),
#  tensor(1.3111, device='cuda:0'),
#  tensor(0.8941, device='cuda:0'),
#  tensor(7.1569, device='cuda:0'),
#  tensor(1.0219, device='cuda:0'),
#  tensor(1.2298, device='cuda:0'),
#  tensor(16.9992, device='cuda:0'),
#  tensor(1.1769, device='cuda:0'),
#  tensor(7.9755, device='cuda:0'),
#  tensor(1.0426, device='cuda:0'),
#  tensor(5.5866, device='cuda:0'),
#  tensor(28.9244, device='cuda:0'),
#  tensor(1.0298, device='cuda:0'),
#  tensor(19.5297, device='cuda:0'),
#  tensor(11.9822, device='cuda:0'),
#  tensor(0.8519, device='cuda:0'),
#  tensor(1.4147, device='cuda:0'),
#  tensor(4.0210, device='cuda:0'),
#  tensor(0.9004, device='cuda:0'),
#  tensor(12.0548, device='cuda:0'),
#  tensor(1.1830, device='cuda:0'),
#  tensor(1.5055, device='cuda:0'),
#  tensor(0.9263, device='cuda:0'),
#  tensor(0.8992, device='cuda:0'),
#  tensor(0.8980, device='cuda:0'),
#  tensor(25.6045, device='cuda:0'),
#  tensor(1.0276, device='cuda:0'),
#  tensor(1.0455, device='cuda:0'),
#  tensor(1.0977, device='cuda:0'),
#  tensor(4.7505, device='cuda:0'),
#  tensor(1.5607, device='cuda:0'),
#  tensor(1.2627, device='cuda:0'),
#  tensor(1.0377, device='cuda:0'),
#  tensor(1.2667, device='cuda:0'),
#  tensor(1.3309, device='cuda:0'),
#  tensor(6.4233, device='cuda:0'),
#  tensor(1.0245, device='cuda:0'),
#  tensor(23.5539, device='cuda:0'),
#  tensor(1.0147, device='cuda:0'),
#  tensor(0.9476, device='cuda:0'),
#  tensor(6.3776, device='cuda:0'),
#  tensor(1.1433, device='cuda:0'),
#  tensor(0.9727, device='cuda:0'),
#  tensor(1.2818, device='cuda:0'),
#  tensor(13.6723, device='cuda:0'),
#  tensor(22.3221, device='cuda:0'),
#  tensor(0.9704, device='cuda:0'),
#  tensor(1.4369, device='cuda:0'),
#  tensor(13.7467, device='cuda:0'),
#  tensor(0.7776, device='cuda:0'),
#  tensor(0.9748, device='cuda:0'),
#  tensor(0.9423, device='cuda:0'),
#  tensor(0.7686, device='cuda:0'),
#  tensor(0.8529, device='cuda:0'),
#  tensor(1.4974, device='cuda:0'),
#  tensor(0.9005, device='cuda:0'),
#  tensor(0.8418, device='cuda:0'),
#  tensor(0.9239, device='cuda:0'),
#  tensor(13.1399, device='cuda:0'),
#  tensor(1.0163, device='cuda:0'),
#  tensor(49.2570, device='cuda:0'),
#  tensor(31.9057, device='cuda:0'),
#  tensor(0.9937, device='cuda:0'),
#  tensor(0.6936, device='cuda:0'),
#  tensor(0.9233, device='cuda:0'),
#  tensor(1.0258, device='cuda:0'),
#  tensor(1.0559, device='cuda:0'),
#  tensor(1.3417, device='cuda:0'),
#  tensor(0.9186, device='cuda:0'),
#  tensor(13.7053, device='cuda:0'),
#  tensor(0.7234, device='cuda:0'),
#  tensor(0.7421, device='cuda:0'),
#  tensor(0.8482, device='cuda:0'),
#  tensor(0.9009, device='cuda:0'),
#  tensor(1.0675, device='cuda:0'),
#  tensor(0.8024, device='cuda:0'),
#  tensor(23.6519, device='cuda:0'),
#  tensor(0.8691, device='cuda:0'),
#  tensor(0.7603, device='cuda:0'),
#  tensor(0.9554, device='cuda:0'),
#  tensor(0.9447, device='cuda:0'),
#  tensor(25.7921, device='cuda:0'),
#  tensor(1.0484, device='cuda:0'),
#  tensor(0.9758, device='cuda:0'),
#  tensor(1.3265, device='cuda:0'),
#  tensor(1.0462, device='cuda:0'),
#  tensor(42.0114, device='cuda:0'),
#  tensor(45.3641, device='cuda:0'),
#  tensor(1.3643, device='cuda:0'),
#  tensor(23.4298, device='cuda:0'),
#  tensor(25.5471, device='cuda:0'),
#  tensor(6.4343, device='cuda:0'),
#  tensor(1.0532, device='cuda:0'),
#  tensor(0.9028, device='cuda:0'),
#  tensor(1.1304, device='cuda:0'),
#  tensor(0.6155, device='cuda:0'),
#  tensor(0.9836, device='cuda:0'),
#  tensor(12.8382, device='cuda:0'),
#  tensor(1.0251, device='cuda:0'),
#  tensor(9.6732, device='cuda:0'),
#  tensor(49.6060, device='cuda:0'),
#  tensor(0.8898, device='cuda:0'),
#  tensor(5.7260, device='cuda:0'),
#  tensor(1.3049, device='cuda:0'),
#  tensor(22.6256, device='cuda:0'),
#  tensor(1.4433, device='cuda:0'),
#  tensor(1.1375, device='cuda:0'),
#  tensor(1.1548, device='cuda:0'),
#  tensor(6.7568, device='cuda:0'),
#  tensor(1.1067, device='cuda:0'),
#  tensor(1.0454, device='cuda:0'),
#  tensor(9.5804, device='cuda:0'),
#  tensor(1.0292, device='cuda:0'),
#  tensor(0.9754, device='cuda:0'),
#  tensor(1.1373, device='cuda:0'),
#  tensor(1.2261, device='cuda:0'),
#  tensor(0.9828, device='cuda:0'),
#  tensor(19.9897, device='cuda:0'),
#  tensor(0.9190, device='cuda:0'),
#  tensor(34.0838, device='cuda:0'),
#  tensor(0.7624, device='cuda:0'),
#  tensor(1.3055, device='cuda:0'),
#  tensor(1.0132, device='cuda:0'),
#  tensor(31.0266, device='cuda:0'),
#  tensor(0.7569, device='cuda:0'),
#  tensor(1.3005, device='cuda:0'),
#  tensor(46.2896, device='cuda:0'),
#  tensor(1.0249, device='cuda:0'),
#  tensor(1.1339, device='cuda:0'),
#  tensor(1.2402, device='cuda:0'),
#  tensor(1.6406, device='cuda:0'),
#  tensor(0.9465, device='cuda:0'),
#  tensor(7.7477, device='cuda:0'),
#  tensor(0.5188, device='cuda:0'),
#  tensor(42.2470, device='cuda:0'),
#  tensor(6.6801, device='cuda:0'),
#  tensor(17.9318, device='cuda:0'),
#  tensor(0.7692, device='cuda:0'),
#  tensor(0.9957, device='cuda:0'),
#  tensor(32.3239, device='cuda:0'),
#  tensor(1.2486, device='cuda:0'),
#  tensor(1.1181, device='cuda:0'),
#  tensor(1.0787, device='cuda:0'),
#  tensor(0.6203, device='cuda:0'),
#  tensor(0.7415, device='cuda:0'),
#  tensor(1.1335, device='cuda:0'),
#  tensor(1.3127, device='cuda:0'),
#  tensor(1.0024, device='cuda:0'),
#  tensor(22.7770, device='cuda:0'),
#  tensor(1.3816, device='cuda:0'),
#  tensor(0.6217, device='cuda:0'),
#  tensor(0.6608, device='cuda:0'),
#  tensor(0.8584, device='cuda:0'),
#  tensor(0.7409, device='cuda:0'),
#  tensor(0.9476, device='cuda:0'),
#  tensor(1.2339, device='cuda:0'),
#  tensor(1.1054, device='cuda:0'),
#  tensor(40.1431, device='cuda:0'),
#  tensor(20.9185, device='cuda:0'),
#  tensor(1.1890, device='cuda:0'),
#  tensor(23.0982, device='cuda:0'),
#  tensor(11.7518, device='cuda:0'),
#  tensor(5.1254, device='cuda:0'),
#  tensor(0.9203, device='cuda:0'),
#  tensor(1.0034, device='cuda:0'),
#  tensor(0.7646, device='cuda:0'),
#  tensor(0.9259, device='cuda:0'),
#  tensor(0.8943, device='cuda:0'),
#  tensor(0.9333, device='cuda:0'),
#  tensor(0.7828, device='cuda:0'),
#  tensor(19.4291, device='cuda:0'),
#  tensor(0.7758, device='cuda:0'),
#  tensor(1.2672, device='cuda:0'),
#  tensor(38.3427, device='cuda:0'),
#  tensor(36.7505, device='cuda:0'),
#  tensor(1.1058, device='cuda:0'),
#  tensor(30.4964, device='cuda:0'),
#  tensor(0.9029, device='cuda:0'),
#  tensor(1.1494, device='cuda:0'),
#  tensor(1.1048, device='cuda:0'),
#  tensor(7.2352, device='cuda:0'),
#  tensor(0.9751, device='cuda:0'),
#  tensor(9.5804, device='cuda:0'),
#  tensor(50.3581, device='cuda:0'),
#  tensor(15.2348, device='cuda:0'),
#  tensor(46.2882, device='cuda:0'),
#  tensor(1.2275, device='cuda:0'),
#  tensor(0.9097, device='cuda:0'),
#  tensor(37.8526, device='cuda:0'),
#  tensor(0.9343, device='cuda:0'),
#  tensor(1.3879, device='cuda:0'),
#  tensor(3.7297, device='cuda:0'),
#  tensor(0.8360, device='cuda:0'),
#  tensor(39.3547, device='cuda:0'),
#  tensor(1.2977, device='cuda:0'),
#  tensor(0.8418, device='cuda:0'),
#  tensor(14.2334, device='cuda:0'),
#  tensor(1.1422, device='cuda:0'),
#  tensor(33.0019, device='cuda:0'),
#  tensor(0.7944, device='cuda:0'),
#  tensor(1.2512, device='cuda:0'),
#  tensor(1.0750, device='cuda:0'),
#  tensor(1.0128, device='cuda:0'),
#  tensor(0.9768, device='cuda:0'),
#  tensor(1.4160, device='cuda:0'),
#  tensor(15.8351, device='cuda:0'),
#  tensor(1.1670, device='cuda:0'),
#  tensor(1.0617, device='cuda:0'),
#  tensor(1.2142, device='cuda:0'),
#  tensor(1.0233, device='cuda:0'),
#  tensor(0.9181, device='cuda:0'),
#  tensor(1.1083, device='cuda:0'),
#  tensor(0.7027, device='cuda:0'),
#  tensor(0.6611, device='cuda:0'),
#  tensor(0.6577, device='cuda:0'),
#  tensor(0.9387, device='cuda:0'),
#  tensor(0.9871, device='cuda:0'),
#  tensor(1.1943, device='cuda:0'),
#  tensor(0.7869, device='cuda:0'),
#  tensor(13.8221, device='cuda:0'),
#  tensor(5.9003, device='cuda:0'),
#  tensor(13.1462, device='cuda:0'),
#  tensor(1.2574, device='cuda:0'),
#  tensor(0.9050, device='cuda:0'),
#  tensor(4.8722, device='cuda:0'),
#  tensor(1.1153, device='cuda:0'),
#  tensor(23.5272, device='cuda:0'),
#  tensor(1.2206, device='cuda:0'),
#  tensor(0.6501, device='cuda:0'),
#  tensor(30.2221, device='cuda:0'),
#  tensor(1.2861, device='cuda:0'),
#  tensor(9.5451, device='cuda:0'),
#  tensor(0.9706, device='cuda:0'),
#  tensor(1.2446, device='cuda:0'),
#  tensor(17.1386, device='cuda:0'),
#  tensor(1.2968, device='cuda:0'),
#  tensor(10.4120, device='cuda:0'),
#  tensor(0.6226, device='cuda:0'),
#  tensor(1.0297, device='cuda:0'),
#  tensor(10.1403, device='cuda:0'),
#  tensor(1.0915, device='cuda:0'),
#  tensor(0.7979, device='cuda:0'),
#  tensor(8.6339, device='cuda:0'),
#  tensor(26.4037, device='cuda:0'),
#  tensor(4.7599, device='cuda:0'),
#  tensor(0.6992, device='cuda:0'),
#  tensor(0.9943, device='cuda:0'),
#  tensor(1.0883, device='cuda:0'),
#  tensor(1.0468, device='cuda:0'),
#  tensor(1.2897, device='cuda:0'),
#  tensor(1.0104, device='cuda:0'),
#  tensor(1.0494, device='cuda:0'),
#  tensor(1.0783, device='cuda:0'),
#  tensor(1.0539, device='cuda:0'),
#  tensor(24.7050, device='cuda:0'),
#  tensor(1.0794, device='cuda:0'),
#  tensor(1.1488, device='cuda:0'),
#  tensor(1.2480, device='cuda:0'),
#  tensor(1.3376, device='cuda:0'),
#  tensor(20.6554, device='cuda:0'),
#  tensor(1.0882, device='cuda:0'),
#  tensor(8.3675, device='cuda:0'),
#  tensor(1.2176, device='cuda:0'),
#  tensor(1.3887, device='cuda:0'),
#  tensor(0.8287, device='cuda:0'),
#  tensor(0.7677, device='cuda:0'),
#  tensor(13.3258, device='cuda:0'),
#  tensor(1.3447, device='cuda:0'),
#  tensor(8.9046, device='cuda:0'),
#  tensor(1.2328, device='cuda:0'),
#  tensor(23.4369, device='cuda:0'),
#  tensor(0.7943, device='cuda:0'),
#  tensor(30.8477, device='cuda:0'),
#  tensor(1.3011, device='cuda:0'),
#  tensor(26.4026, device='cuda:0'),
#  tensor(3.9421, device='cuda:0'),
#  tensor(1.1705, device='cuda:0'),
#  tensor(1.0638, device='cuda:0'),
#  tensor(22.1282, device='cuda:0'),
#  tensor(1.4178, device='cuda:0'),
#  tensor(1.0542, device='cuda:0'),
#  tensor(0.7601, device='cuda:0'),
#  tensor(28.0309, device='cuda:0'),
#  tensor(0.8263, device='cuda:0'),
#  tensor(9.9238, device='cuda:0'),
#  tensor(0.8758, device='cuda:0'),
#  tensor(0.9934, device='cuda:0'),
#  tensor(1.6376, device='cuda:0'),
#  tensor(0.9937, device='cuda:0'),
#  tensor(0.9350, device='cuda:0'),
#  tensor(13.2232, device='cuda:0'),
#  tensor(1.3404, device='cuda:0'),
#  tensor(8.5360, device='cuda:0'),
#  tensor(16.6730, device='cuda:0'),
#  tensor(36.7724, device='cuda:0'),
#  tensor(47.2782, device='cuda:0'),
#  tensor(5.9124, device='cuda:0'),
#  tensor(1.0513, device='cuda:0'),
#  tensor(24.0397, device='cuda:0'),
#  tensor(12.7087, device='cuda:0'),
#  tensor(3.7913, device='cuda:0'),
#  tensor(0.8237, device='cuda:0'),
#  tensor(0.8713, device='cuda:0'),
#  tensor(1.1203, device='cuda:0'),
#  tensor(0.8294, device='cuda:0'),
#  tensor(1.0345, device='cuda:0'),
#  tensor(0.7466, device='cuda:0'),
#  tensor(1.0428, device='cuda:0'),
#  tensor(0.7494, device='cuda:0'),
#  tensor(1.2146, device='cuda:0'),
#  tensor(1.1542, device='cuda:0'),
#  tensor(1.4315, device='cuda:0'),
#  tensor(0.7675, device='cuda:0'),
#  tensor(1.5179, device='cuda:0'),
#  tensor(1.0628, device='cuda:0'),
#  tensor(7.9883, device='cuda:0'),
#  tensor(10.1484, device='cuda:0'),
#  tensor(18.4750, device='cuda:0'),
#  tensor(0.9368, device='cuda:0'),
#  tensor(0.7177, device='cuda:0'),
#  tensor(0.7938, device='cuda:0'),
#  tensor(0.7137, device='cuda:0'),
#  tensor(0.6582, device='cuda:0'),
#  tensor(1.0749, device='cuda:0'),
#  tensor(0.7699, device='cuda:0'),
#  tensor(0.9564, device='cuda:0'),
#  tensor(1.0811, device='cuda:0'),
#  tensor(1.0032, device='cuda:0'),
#  tensor(1.6858, device='cuda:0'),
#  tensor(12.7068, device='cuda:0'),
#  tensor(13.9609, device='cuda:0'),
#  tensor(1.2564, device='cuda:0'),
#  tensor(11.5587, device='cuda:0'),
#  tensor(0.9887, device='cuda:0'),
#  tensor(18.8248, device='cuda:0'),
#  tensor(5.4527, device='cuda:0'),
#  tensor(1.5139, device='cuda:0'),
#  tensor(1.1702, device='cuda:0'),
#  tensor(1.8040, device='cuda:0'),
#  tensor(9.1430, device='cuda:0'),
#  tensor(0.9558, device='cuda:0'),
#  tensor(0.5474, device='cuda:0'),
#  tensor(0.8889, device='cuda:0'),
#  tensor(31.7458, device='cuda:0'),
#  tensor(1.2113, device='cuda:0'),
#  tensor(14.7773, device='cuda:0'),
#  tensor(0.9406, device='cuda:0'),
#  tensor(1.0647, device='cuda:0'),
#  tensor(0.8265, device='cuda:0'),
#  tensor(21.4610, device='cuda:0'),
#  tensor(0.7922, device='cuda:0'),
#  tensor(8.6793, device='cuda:0'),
#  tensor(0.8087, device='cuda:0'),
#  tensor(53.1919, device='cuda:0'),
#  tensor(0.9564, device='cuda:0'),
#  tensor(1.0427, device='cuda:0'),
#  tensor(1.1101, device='cuda:0'),
#  tensor(1.4695, device='cuda:0'),
#  tensor(1.3439, device='cuda:0'),
#  tensor(41.6857, device='cuda:0'),
#  tensor(0.8488, device='cuda:0'),
#  tensor(1.0620, device='cuda:0'),
#  tensor(0.8771, device='cuda:0'),
#  tensor(19.3286, device='cuda:0'),
#  tensor(1.1988, device='cuda:0'),
#  tensor(0.9672, device='cuda:0'),
#  tensor(25.5959, device='cuda:0'),
#  tensor(10.1257, device='cuda:0'),
#  tensor(0.7651, device='cuda:0'),
#  tensor(1.1412, device='cuda:0'),
#  tensor(1.2443, device='cuda:0'),
#  tensor(0.6498, device='cuda:0'),
#  tensor(1.2030, device='cuda:0'),
#  tensor(0.7644, device='cuda:0'),
#  tensor(1.1673, device='cuda:0'),
#  tensor(0.8868, device='cuda:0'),
#  tensor(0.7022, device='cuda:0'),
#  tensor(0.8728, device='cuda:0'),
#  tensor(1.0599, device='cuda:0'),
#  tensor(1.1293, device='cuda:0'),
#  tensor(16.0952, device='cuda:0'),
#  tensor(0.7601, device='cuda:0'),
#  tensor(0.9995, device='cuda:0'),
#  tensor(12.5559, device='cuda:0'),
#  tensor(0.6460, device='cuda:0'),
#  tensor(0.9868, device='cuda:0'),
#  tensor(1.5180, device='cuda:0'),
#  tensor(1.1866, device='cuda:0'),
#  tensor(1.1611, device='cuda:0'),
#  tensor(1.0983, device='cuda:0'),
#  tensor(1.1972, device='cuda:0'),
#  tensor(6.1586, device='cuda:0'),
#  tensor(5.0087, device='cuda:0'),
#  tensor(19.7838, device='cuda:0'),
#  tensor(19.8646, device='cuda:0'),
#  tensor(1.2570, device='cuda:0'),
#  tensor(1.0187, device='cuda:0'),
#  tensor(1.0873, device='cuda:0'),
#  tensor(1.1194, device='cuda:0'),
#  tensor(6.9300, device='cuda:0'),
#  tensor(6.9605, device='cuda:0'),
#  tensor(13.8860, device='cuda:0'),
#  tensor(0.9225, device='cuda:0'),
#  tensor(1.8247, device='cuda:0'),
#  tensor(0.8263, device='cuda:0'),
#  tensor(13.1201, device='cuda:0'),
#  tensor(28.0125, device='cuda:0'),
#  tensor(0.8372, device='cuda:0'),
#  tensor(0.7879, device='cuda:0'),
#  tensor(1.1138, device='cuda:0'),
#  tensor(0.9920, device='cuda:0'),
#  tensor(7.4013, device='cuda:0'),
#  tensor(0.8773, device='cuda:0'),
#  tensor(10.3635, device='cuda:0'),
#  tensor(3.8062, device='cuda:0'),
#  tensor(1.1700, device='cuda:0'),
#  tensor(1.0081, device='cuda:0'),
#  tensor(28.8469, device='cuda:0'),
#  tensor(6.8650, device='cuda:0'),
#  tensor(1.1354, device='cuda:0'),
#  tensor(1.0580, device='cuda:0'),
#  tensor(9.3437, device='cuda:0'),
#  tensor(1.0523, device='cuda:0'),
#  tensor(1.2314, device='cuda:0'),
#  tensor(5.7756, device='cuda:0'),
#  tensor(0.9107, device='cuda:0'),
#  tensor(2.7742, device='cuda:0'),
#  tensor(5.4681, device='cuda:0'),
#  tensor(3.0057, device='cuda:0'),
#  tensor(1.0464, device='cuda:0'),
#  tensor(22.9331, device='cuda:0'),
#  tensor(0.9492, device='cuda:0'),
#  tensor(1.1027, device='cuda:0'),
#  tensor(15.7489, device='cuda:0'),
#  tensor(6.0753, device='cuda:0'),
#  tensor(1.1682, device='cuda:0'),
#  tensor(1.0468, device='cuda:0'),
#  tensor(1.0923, device='cuda:0'),
#  tensor(1.3858, device='cuda:0'),
#  tensor(23.3103, device='cuda:0'),
#  tensor(1.1684, device='cuda:0'),
#  tensor(0.6995, device='cuda:0'),
#  tensor(3.9966, device='cuda:0'),
#  tensor(1.0305, device='cuda:0'),
#  tensor(0.7863, device='cuda:0'),
#  tensor(18.2006, device='cuda:0'),
#  tensor(1.0840, device='cuda:0'),
#  tensor(0.6265, device='cuda:0'),
#  tensor(9.1016, device='cuda:0'),
#  tensor(0.9489, device='cuda:0'),
#  tensor(1.2010, device='cuda:0'),
#  tensor(1.2205, device='cuda:0'),
#  tensor(1.0831, device='cuda:0'),
#  tensor(36.6744, device='cuda:0'),
#  tensor(1.7404, device='cuda:0'),
#  tensor(24.3689, device='cuda:0'),
#  tensor(1.0452, device='cuda:0'),
#  tensor(1.2098, device='cuda:0'),
#  tensor(0.8055, device='cuda:0'),
#  tensor(0.6322, device='cuda:0'),
#  tensor(6.7678, device='cuda:0'),
#  tensor(13.4401, device='cuda:0'),
#  tensor(1.0747, device='cuda:0'),
#  tensor(0.7878, device='cuda:0'),
#  tensor(17.3605, device='cuda:0'),
#  tensor(0.8894, device='cuda:0'),
#  tensor(0.9534, device='cuda:0'),
#  tensor(1.2442, device='cuda:0'),
#  tensor(15.8016, device='cuda:0'),
#  tensor(17.9929, device='cuda:0'),
#  tensor(0.7428, device='cuda:0'),
#  tensor(0.9229, device='cuda:0'),
#  tensor(1.0007, device='cuda:0'),
#  tensor(1.0282, device='cuda:0'),
#  tensor(1.7290, device='cuda:0'),
#  tensor(0.9247, device='cuda:0'),
#  tensor(7.0435, device='cuda:0'),
#  tensor(1.5391, device='cuda:0'),
#  tensor(19.8281, device='cuda:0'),
#  tensor(20.4320, device='cuda:0'),
#  tensor(1.1450, device='cuda:0'),
#  tensor(30.0225, device='cuda:0'),
#  tensor(15.7111, device='cuda:0'),
#  tensor(2.4084, device='cuda:0'),
#  tensor(1.3927, device='cuda:0'),
#  tensor(0.7128, device='cuda:0'),
#  tensor(5.9817, device='cuda:0'),
#  tensor(13.9288, device='cuda:0'),
#  tensor(0.8731, device='cuda:0'),
#  tensor(7.8164, device='cuda:0'),
#  tensor(1.1161, device='cuda:0'),
#  tensor(0.8293, device='cuda:0'),
#  tensor(1.0801, device='cuda:0'),
#  tensor(11.0376, device='cuda:0'),
#  tensor(15.3541, device='cuda:0'),
#  tensor(0.8286, device='cuda:0'),
#  tensor(0.8617, device='cuda:0'),
#  tensor(0.9517, device='cuda:0'),
#  tensor(0.9833, device='cuda:0'),
#  tensor(0.8942, device='cuda:0'),
#  tensor(18.8447, device='cuda:0'),
#  tensor(0.7324, device='cuda:0'),
#  tensor(1.0346, device='cuda:0'),
#  tensor(23.1561, device='cuda:0'),
#  tensor(7.7344, device='cuda:0'),
#  tensor(0.8685, device='cuda:0'),
#  tensor(1.3627, device='cuda:0'),
#  tensor(20.8427, device='cuda:0'),
#  tensor(0.7357, device='cuda:0'),
#  tensor(15.1966, device='cuda:0'),
#  tensor(7.1252, device='cuda:0'),
#  tensor(0.8739, device='cuda:0'),
#  tensor(1.1617, device='cuda:0'),
#  tensor(1.0778, device='cuda:0'),
#  tensor(17.9329, device='cuda:0'),
#  tensor(27.7995, device='cuda:0'),
#  tensor(1.2152, device='cuda:0'),
#  tensor(0.5637, device='cuda:0'),
#  tensor(1.0060, device='cuda:0'),
#  tensor(5.8904, device='cuda:0'),
#  tensor(0.8168, device='cuda:0'),
#  tensor(1.3260, device='cuda:0'),
#  tensor(1.0085, device='cuda:0'),
#  tensor(27.7371, device='cuda:0'),
#  tensor(1.0200, device='cuda:0'),
#  tensor(1.1066, device='cuda:0'),
#  tensor(2.7036, device='cuda:0'),
#  tensor(0.7527, device='cuda:0'),
#  tensor(0.9678, device='cuda:0'),
#  tensor(0.7173, device='cuda:0'),
#  tensor(11.9818, device='cuda:0'),
#  tensor(0.7517, device='cuda:0'),
#  tensor(1.0321, device='cuda:0'),
#  tensor(3.5729, device='cuda:0'),
#  tensor(7.0924, device='cuda:0'),
#  tensor(1.1314, device='cuda:0'),
#  tensor(0.9773, device='cuda:0'),
#  tensor(9.0109, device='cuda:0'),
#  tensor(1.0480, device='cuda:0'),
#  tensor(10.9004, device='cuda:0'),
#  tensor(1.1729, device='cuda:0'),
#  tensor(0.9681, device='cuda:0'),
#  tensor(0.9994, device='cuda:0'),
#  tensor(9.8814, device='cuda:0'),
#  tensor(6.8387, device='cuda:0'),
#  tensor(1.1570, device='cuda:0'),
#  tensor(0.9471, device='cuda:0'),
#  tensor(27.9314, device='cuda:0'),
#  tensor(27.3489, device='cuda:0'),
#  tensor(0.8916, device='cuda:0'),
#  tensor(1.1514, device='cuda:0'),
#  tensor(1.0029, device='cuda:0'),
#  tensor(1.0241, device='cuda:0'),
#  tensor(0.8746, device='cuda:0'),
#  tensor(10.1988, device='cuda:0'),
#  tensor(1.2194, device='cuda:0'),
#  tensor(1.0399, device='cuda:0'),
#  tensor(1.3043, device='cuda:0'),
#  tensor(12.3665, device='cuda:0'),
#  tensor(28.3887, device='cuda:0'),
#  tensor(0.9420, device='cuda:0'),
#  tensor(25.9288, device='cuda:0'),
#  tensor(29.8135, device='cuda:0'),
#  tensor(0.8306, device='cuda:0'),
#  tensor(1.0839, device='cuda:0'),
#  tensor(1.1313, device='cuda:0'),
#  tensor(0.7054, device='cuda:0'),
#  tensor(0.9928, device='cuda:0'),
#  tensor(24.1581, device='cuda:0'),
#  tensor(21.2960, device='cuda:0'),
#  tensor(17.5365, device='cuda:0'),
#  tensor(2.3087, device='cuda:0'),
#  tensor(1.2354, device='cuda:0'),
#  tensor(1.2071, device='cuda:0'),
#  tensor(0.9592, device='cuda:0'),
#  tensor(1.1776, device='cuda:0'),
#  tensor(0.9162, device='cuda:0'),
#  tensor(0.9029, device='cuda:0'),
#  tensor(0.8256, device='cuda:0'),
#  tensor(40.7004, device='cuda:0'),
#  tensor(31.7672, device='cuda:0'),
#  tensor(8.8413, device='cuda:0'),
#  tensor(1.1276, device='cuda:0'),
#  tensor(0.9164, device='cuda:0'),
#  tensor(21.1137, device='cuda:0'),
#  tensor(1.1664, device='cuda:0'),
#  tensor(9.7284, device='cuda:0'),
#  tensor(18.6770, device='cuda:0'),
#  tensor(0.9240, device='cuda:0'),
#  tensor(31.4350, device='cuda:0'),
#  tensor(4.9663, device='cuda:0'),
#  tensor(24.3159, device='cuda:0'),
#  tensor(0.9224, device='cuda:0'),
#  tensor(1.3639, device='cuda:0'),
#  tensor(0.7998, device='cuda:0'),
#  tensor(1.2553, device='cuda:0'),
#  tensor(17.1333, device='cuda:0'),
#  tensor(1.0752, device='cuda:0'),
#  tensor(1.2722, device='cuda:0'),
#  tensor(1.2647, device='cuda:0'),
#  tensor(1.2426, device='cuda:0'),
#  tensor(1.1822, device='cuda:0'),
#  tensor(1.2300, device='cuda:0'),
#  tensor(17.8546, device='cuda:0'),
#  tensor(1.0262, device='cuda:0'),
#  tensor(0.8960, device='cuda:0'),
#  tensor(1.1833, device='cuda:0'),
#  tensor(41.1605, device='cuda:0'),
#  tensor(1.0047, device='cuda:0'),
#  tensor(13.7127, device='cuda:0'),
#  tensor(1.5392, device='cuda:0'),
#  tensor(0.6797, device='cuda:0'),
#  tensor(2.0176, device='cuda:0'),
#  tensor(0.9233, device='cuda:0'),
#  tensor(1.0670, device='cuda:0'),
#  tensor(4.7993, device='cuda:0'),
#  tensor(25.0092, device='cuda:0'),
#  tensor(0.8239, device='cuda:0'),
#  tensor(1.1963, device='cuda:0'),
#  tensor(56.6808, device='cuda:0'),
#  tensor(1.0187, device='cuda:0'),
#  tensor(1.0026, device='cuda:0'),
#  tensor(0.8426, device='cuda:0'),
#  tensor(14.2128, device='cuda:0'),
#  tensor(1.0139, device='cuda:0'),
#  tensor(1.3188, device='cuda:0'),
#  tensor(1.2397, device='cuda:0'),
#  tensor(0.7653, device='cuda:0'),
#  tensor(10.2993, device='cuda:0'),
#  tensor(0.9198, device='cuda:0'),
#  tensor(1.0569, device='cuda:0'),
#  tensor(0.9970, device='cuda:0'),
#  tensor(1.1692, device='cuda:0'),
#  tensor(0.9193, device='cuda:0'),
#  tensor(1.3564, device='cuda:0'),
#  tensor(17.0664, device='cuda:0'),
#  tensor(1.1061, device='cuda:0'),
#  tensor(0.9385, device='cuda:0'),
#  tensor(1.2132, device='cuda:0'),
#  tensor(1.1050, device='cuda:0'),
#  tensor(24.4147, device='cuda:0'),
#  tensor(0.9269, device='cuda:0'),
#  tensor(1.1604, device='cuda:0'),
#  tensor(52.1058, device='cuda:0'),
#  tensor(0.8545, device='cuda:0'),
#  tensor(0.9817, device='cuda:0'),
#  tensor(10.1649, device='cuda:0'),
#  tensor(1.6910, device='cuda:0'),
#  tensor(0.7370, device='cuda:0'),
#  tensor(13.3316, device='cuda:0'),
#  tensor(1.4246, device='cuda:0'),
#  tensor(0.6568, device='cuda:0'),
#  tensor(22.2594, device='cuda:0'),
#  tensor(1.2506, device='cuda:0'),
#  tensor(0.8968, device='cuda:0'),
#  tensor(12.7550, device='cuda:0'),
#  tensor(10.5619, device='cuda:0'),
#  tensor(0.7862, device='cuda:0'),
#  tensor(0.8491, device='cuda:0'),
#  tensor(0.9172, device='cuda:0'),
#  tensor(8.0191, device='cuda:0'),
#  tensor(1.0398, device='cuda:0'),
#  tensor(0.8464, device='cuda:0'),
#  tensor(0.8591, device='cuda:0'),
#  tensor(1.1163, device='cuda:0'),
#  tensor(1.3215, device='cuda:0'),
#  tensor(1.3059, device='cuda:0'),
#  tensor(5.7950, device='cuda:0'),
#  tensor(1.0355, device='cuda:0'),
#  tensor(0.9699, device='cuda:0'),
#  tensor(29.0372, device='cuda:0'),
#  tensor(0.8786, device='cuda:0'),
#  tensor(6.2420, device='cuda:0'),
#  tensor(1.0580, device='cuda:0'),
#  tensor(17.0874, device='cuda:0'),
#  tensor(0.8979, device='cuda:0'),
#  tensor(0.9500, device='cuda:0'),
#  tensor(1.0890, device='cuda:0'),
#  tensor(1.0100, device='cuda:0'),
#  tensor(34.8469, device='cuda:0'),
#  tensor(0.9789, device='cuda:0'),
#  tensor(20.3877, device='cuda:0'),
#  tensor(0.8959, device='cuda:0'),
#  tensor(1.0624, device='cuda:0'),
#  tensor(1.6037, device='cuda:0'),
#  tensor(0.8396, device='cuda:0'),
#  tensor(1.0751, device='cuda:0'),
#  tensor(3.7718, device='cuda:0'),
#  tensor(7.5343, device='cuda:0'),
#  tensor(0.9250, device='cuda:0'),
#  tensor(1.0431, device='cuda:0'),
#  tensor(17.6652, device='cuda:0'),
#  tensor(18.5584, device='cuda:0'),
#  tensor(2.7635e+10, device='cuda:0'),
#  tensor(3.1665, device='cuda:0'),
#  tensor(23.4149, device='cuda:0'),
#  tensor(0.7594, device='cuda:0'),
#  tensor(1.0546, device='cuda:0'),
#  tensor(25.8597, device='cuda:0'),
#  tensor(0.8931, device='cuda:0'),
#  tensor(0.9363, device='cuda:0'),
#  tensor(1.1416, device='cuda:0'),
#  tensor(1.0483, device='cuda:0'),
#  tensor(1.0394, device='cuda:0'),
#  tensor(9.5210, device='cuda:0'),
#  tensor(3.2713, device='cuda:0'),
#  tensor(0.8789, device='cuda:0'),
#  tensor(1.3608, device='cuda:0'),
#  tensor(1.1033, device='cuda:0'),
#  tensor(0.9871, device='cuda:0'),
#  tensor(1.0606, device='cuda:0'),
#  tensor(10.6166, device='cuda:0'),
#  tensor(0.9427, device='cuda:0'),
#  tensor(1.4106, device='cuda:0'),
#  tensor(17.8821, device='cuda:0'),
#  tensor(0.9574, device='cuda:0'),
#  tensor(0.6539, device='cuda:0'),
#  tensor(8.1571, device='cuda:0'),
#  tensor(1.0998, device='cuda:0'),
#  tensor(0.9726, device='cuda:0'),
#  tensor(20.2913, device='cuda:0'),
#  tensor(14.5358, device='cuda:0'),
#  tensor(0.9939, device='cuda:0'),
#  tensor(1.0365, device='cuda:0'),
#  tensor(0.6622, device='cuda:0'),
#  tensor(0.5911, device='cuda:0'),
#  tensor(0.7013, device='cuda:0'),
#  tensor(1.1105, device='cuda:0'),
#  tensor(0.9909, device='cuda:0'),
#  tensor(4.7413, device='cuda:0'),
#  tensor(1.0270, device='cuda:0'),
#  tensor(3.6613, device='cuda:0'),
#  tensor(1.0563, device='cuda:0'),
#  tensor(1.2585, device='cuda:0'),
#  tensor(0.7039, device='cuda:0'),
#  tensor(0.9331, device='cuda:0'),
#  tensor(1.1579, device='cuda:0'),
#  tensor(1.0526, device='cuda:0'),
#  tensor(0.8761, device='cuda:0'),
#  tensor(0.8415, device='cuda:0'),
#  tensor(0.8114, device='cuda:0'),
#  tensor(1.1445, device='cuda:0'),
#  tensor(1.2063, device='cuda:0'),
#  tensor(1.3513, device='cuda:0'),
#  tensor(1.1406, device='cuda:0'),
#  tensor(1.1808, device='cuda:0'),
#  tensor(1.6514, device='cuda:0'),
#  tensor(0.9400, device='cuda:0'),
#  tensor(1.0552, device='cuda:0'),
#  tensor(1.0947, device='cuda:0'),
#  tensor(0.8486, device='cuda:0'),
#  tensor(1.2361, device='cuda:0'),
#  tensor(0.9720, device='cuda:0'),
#  tensor(0.8216, device='cuda:0'),
#  tensor(1.5050, device='cuda:0'),
#  tensor(0.9236, device='cuda:0'),
#  tensor(0.7431, device='cuda:0'),
#  tensor(0.8889, device='cuda:0'),
#  tensor(1.2232, device='cuda:0'),
#  tensor(1.3505, device='cuda:0'),
#  tensor(32.1497, device='cuda:0'),
#  tensor(1.0779, device='cuda:0'),
#  tensor(1.0650, device='cuda:0'),
#  tensor(21.4875, device='cuda:0'),
#  tensor(0.6917, device='cuda:0'),
#  tensor(1.0427, device='cuda:0'),
#  tensor(1.2007, device='cuda:0'),
#  tensor(1.0931, device='cuda:0'),
#  tensor(0.8647, device='cuda:0'),
#  tensor(1.2425, device='cuda:0'),
#  tensor(0.5524, device='cuda:0'),
#  tensor(2.6639, device='cuda:0'),
#  tensor(0.9293, device='cuda:0'),
#  tensor(0.9621, device='cuda:0'),
#  tensor(0.8909, device='cuda:0'),
#  tensor(27.5555, device='cuda:0'),
#  tensor(0.9264, device='cuda:0'),
#  tensor(1.2925, device='cuda:0'),
#  tensor(1.2052, device='cuda:0'),
#  tensor(0.9951, device='cuda:0'),
#  tensor(0.8965, device='cuda:0'),
#  tensor(0.9220, device='cuda:0'),
#  tensor(10.5958, device='cuda:0'),
#  tensor(0.6617, device='cuda:0'),
#  tensor(0.9463, device='cuda:0'),
#  tensor(1.0575, device='cuda:0'),
#  tensor(0.9156, device='cuda:0'),
#  tensor(1.1026, device='cuda:0'),
#  tensor(1.3542, device='cuda:0'),
#  tensor(26.4921, device='cuda:0'),
#  tensor(0.9476, device='cuda:0'),
#  tensor(1.2296, device='cuda:0'),
#  tensor(44.0677, device='cuda:0'),
#  tensor(1.1732, device='cuda:0'),
#  tensor(3.1213, device='cuda:0'),
#  tensor(18.2300, device='cuda:0'),
#  tensor(1.0938, device='cuda:0'),
#  tensor(17.7646, device='cuda:0'),
#  tensor(1.0557, device='cuda:0'),
#  tensor(1.1276, device='cuda:0'),
#  tensor(1.2649, device='cuda:0'),
#  tensor(0.8378, device='cuda:0'),
#  tensor(1.1215, device='cuda:0'),
#  tensor(1.2423, device='cuda:0'),
#  tensor(39.2463, device='cuda:0'),
#  tensor(0.8782, device='cuda:0'),
#  tensor(28.2631, device='cuda:0'),
#  tensor(3.5917, device='cuda:0'),
#  tensor(6.0665, device='cuda:0'),
#  tensor(0.9183, device='cuda:0'),
#  tensor(1.0172, device='cuda:0'),
#  tensor(14.4486, device='cuda:0'),
#  tensor(1.2539, device='cuda:0'),
#  tensor(27.3338, device='cuda:0'),
#  tensor(7.4439, device='cuda:0'),
#  tensor(15.4658, device='cuda:0'),
#  tensor(0.9874, device='cuda:0'),
#  tensor(0.9682, device='cuda:0'),
#  tensor(0.9329, device='cuda:0'),
#  tensor(8.2864, device='cuda:0'),
#  tensor(32.2211, device='cuda:0'),
#  tensor(0.8039, device='cuda:0'),
#  tensor(8.3894, device='cuda:0'),
#  tensor(27.8971, device='cuda:0'),
#  tensor(18.8303, device='cuda:0'),
#  tensor(2.7813, device='cuda:0'),
#  tensor(1.2165, device='cuda:0'),
#  tensor(10.1917, device='cuda:0'),
#  tensor(0.9532, device='cuda:0'),
#  tensor(1.1397, device='cuda:0'),
#  tensor(31.7728, device='cuda:0'),
#  tensor(0.9016, device='cuda:0'),
#  tensor(1.2715, device='cuda:0'),
#  tensor(0.9529, device='cuda:0'),
#  tensor(1.0890, device='cuda:0'),
#  tensor(38.0679, device='cuda:0'),
#  tensor(8.3052, device='cuda:0'),
#  tensor(13.5982, device='cuda:0'),
#  tensor(1.0650, device='cuda:0'),
#  tensor(1.3620, device='cuda:0'),
#  tensor(10.3330, device='cuda:0'),
#  tensor(0.8063, device='cuda:0'),
#  tensor(0.8750, device='cuda:0'),
#  tensor(17.5840, device='cuda:0'),
#  tensor(26.4333, device='cuda:0'),
#  tensor(6.2402, device='cuda:0'),
#  tensor(16.6631, device='cuda:0'),
#  tensor(1.0056, device='cuda:0'),
#  tensor(1.1482, device='cuda:0'),
#  tensor(0.7606, device='cuda:0'),
#  tensor(1.2577, device='cuda:0'),
#  tensor(1.1014, device='cuda:0'),
#  tensor(0.7452, device='cuda:0'),
#  tensor(20.6524, device='cuda:0'),
#  tensor(19.7879, device='cuda:0'),
#  tensor(15.7193, device='cuda:0'),
#  tensor(1.2667, device='cuda:0'),
#  tensor(5.0496, device='cuda:0'),
#  tensor(0.7333, device='cuda:0'),
#  tensor(35.7210, device='cuda:0'),
#  tensor(22.0280, device='cuda:0'),
#  tensor(1.2761, device='cuda:0'),
#  tensor(5.7133, device='cuda:0'),
#  tensor(0.7772, device='cuda:0'),
#  tensor(1.1244, device='cuda:0'),
#  tensor(1.0898, device='cuda:0'),
#  tensor(0.8993, device='cuda:0'),
#  tensor(1.2692, device='cuda:0'),
#  tensor(1.0405, device='cuda:0'),
#  tensor(14.1684, device='cuda:0'),
#  tensor(1.4653, device='cuda:0'),
#  tensor(25.4543, device='cuda:0'),
#  tensor(0.7301, device='cuda:0'),
#  tensor(0.7724, device='cuda:0'),
#  tensor(1.0467, device='cuda:0'),
#  tensor(23.9064, device='cuda:0'),
#  tensor(8.1549, device='cuda:0'),
#  tensor(0.6961, device='cuda:0'),
#  tensor(6.5503, device='cuda:0'),
#  tensor(1.0714, device='cuda:0'),
#  tensor(26.5837, device='cuda:0'),
#  tensor(1.0088, device='cuda:0'),
#  tensor(32.3754, device='cuda:0'),
#  tensor(0.6188, device='cuda:0'),
#  tensor(0.7331, device='cuda:0'),
#  tensor(0.9832, device='cuda:0'),
#  tensor(1.0437, device='cuda:0'),
#  tensor(16.3485, device='cuda:0'),
#  tensor(28.4119, device='cuda:0'),
#  tensor(10.6085, device='cuda:0'),
#  tensor(0.8948, device='cuda:0'),
#  tensor(1.4209, device='cuda:0'),
#  tensor(1.1637, device='cuda:0'),
#  tensor(0.7265, device='cuda:0'),
#  tensor(0.9097, device='cuda:0'),
#  tensor(0.9234, device='cuda:0'),
#  tensor(0.8190, device='cuda:0'),
#  tensor(0.8217, device='cuda:0'),
#  tensor(1.1461, device='cuda:0'),
#  tensor(0.8073, device='cuda:0'),
#  tensor(0.8788, device='cuda:0'),
#  tensor(1.2181, device='cuda:0'),
#  tensor(1.1245, device='cuda:0'),
#  tensor(0.9748, device='cuda:0'),
#  tensor(0.6177, device='cuda:0'),
#  tensor(0.7997, device='cuda:0'),
#  tensor(1.3125, device='cuda:0'),
#  tensor(7.3467, device='cuda:0'),
#  tensor(1.0518, device='cuda:0'),
#  tensor(1.2365, device='cuda:0'),
#  tensor(0.9846, device='cuda:0'),
#  tensor(1.0462, device='cuda:0'),
#  tensor(0.9966, device='cuda:0'),
#  tensor(0.8933, device='cuda:0'),
#  tensor(0.9934, device='cuda:0'),
#  tensor(4.2667, device='cuda:0'),
#  tensor(11.9493, device='cuda:0'),
#  tensor(1.0395, device='cuda:0'),
#  tensor(1.0074, device='cuda:0'),
#  tensor(1.2069, device='cuda:0'),
#  tensor(1.0327, device='cuda:0'),
#  tensor(33.9020, device='cuda:0'),
#  tensor(1.3081, device='cuda:0'),
#  tensor(26.5533, device='cuda:0'),
#  tensor(2.5604, device='cuda:0'),
#  tensor(1.7089, device='cuda:0'),
#  tensor(1.6264, device='cuda:0'),
#  tensor(13.7432, device='cuda:0'),
#  tensor(1.0453, device='cuda:0'),
#  tensor(0.9988, device='cuda:0'),
#  tensor(1.4763, device='cuda:0'),
#  tensor(32.3503, device='cuda:0'),
#  tensor(5.4294, device='cuda:0'),
#  tensor(16.5644, device='cuda:0'),
#  tensor(1.0343, device='cuda:0'),
#  tensor(14.8730, device='cuda:0'),
#  tensor(85.5362, device='cuda:0'),
#  tensor(1.0534, device='cuda:0'),
#  tensor(0.7758, device='cuda:0'),
#  tensor(31.5506, device='cuda:0'),
#  tensor(1.1042, device='cuda:0'),
#  tensor(1.0199, device='cuda:0'),
#  tensor(24.7695, device='cuda:0'),
#  tensor(12.1176, device='cuda:0'),
#  tensor(33.6240, device='cuda:0'),
#  tensor(1.1005, device='cuda:0'),
#  tensor(0.8870, device='cuda:0'),
#  tensor(0.9682, device='cuda:0'),
#  tensor(0.9404, device='cuda:0'),
#  tensor(0.8639, device='cuda:0'),
#  tensor(0.8126, device='cuda:0'),
#  tensor(1.5244, device='cuda:0'),
#  tensor(1.0537, device='cuda:0'),
#  tensor(26.9457, device='cuda:0'),
#  tensor(1.1970, device='cuda:0'),
#  tensor(0.8453, device='cuda:0'),
#  tensor(0.9026, device='cuda:0')]

# %%
# W = torch.randn((batchsize, DIM, DIM), device=device) # represents IID
# Y = torch.randn((batchsize,DIM),device=device)
# x = torch.zeros((batchsize,DIM),device=device,requires_grad=True)

# state=None#初始化LSTM hidden state
# H=torch.eye(DIM, device=x.device, dtype=x.dtype,requires_grad=True).unsqueeze(0).expand(batchsize, -1, -1)
# steps=20
# mem_loss=[]#初始化loss的list
# loss=f(W,Y,x)#每个case的loss
# global_loss_graph = 0#记录每个迭代的总loss 用于后向传播
# lossmean=loss.mean()#总loss的平均值

# global_loss_graph+=lossmean
# mem_loss.append(lossmean.clone().detach())

# lossmean.backward(retain_graph=True)
# g = x.grad.clone()#g detach掉
# d=-torch.matmul(H,g.unsqueeze(2))
# k=0
# #print(loss)
# for i in range(steps):
#     g_pre=g.clone()# 保存g作为上一次的g，此时g_pre不在计算图中
#     # alpha=strong_wolfe(W,Y,batchsize,f, x, d, loss, g, c1=1e-4, c2=0.9, max_iter=10,device=device)
#     # alpha.detach_()
#     # update=alpha*d.squeeze()
#     update=d.squeeze()
#     x=x+update
#     x.retain_grad()
#     loss=f(W,Y,x)
#     lossmean=loss.mean()
#     global_loss_graph+=lossmean
#     mem_loss.append(lossmean.clone().detach())
#     #print(mem_loss[0])
#     lossmean.backward(retain_graph=True)
#     print([i.grad for i in LSTM_motify.parameters()])
#     #print(g)
#     g = x.grad.clone()
#     #print(torch.norm(g,dim=1).mean())
#     if(sum(torch.norm(g,dim=1)<acc)>0):
#         break
#     #print(B.H)
#     input_vec=torch.cat((g,update),dim=1).unsqueeze(0)
#     #print(input_vec.is_leaf)
#     motify,state=LSTM_motify(input_vec,state)
#     H = H.clone() + motify.reshape((batchsize, DIM, DIM))
#     H.retain_grad()
#     d=-torch.matmul(H,g.unsqueeze(2))
#     k+=1
# plt.plot([i.cpu().detach().numpy() for i in mem_loss],label='LSTM_before_train')

# %%
W = torch.randn((batchsize, DIM, DIM), device=device) # represents IID
Y = torch.randn((batchsize,DIM),device=device)
x = torch.zeros((batchsize,DIM),device=device,requires_grad=True)
steps=40
state=None
H=BFGS(batchsize,DIM,device).I
mem_loss=[]
loss=f(W,Y,x)
acc=1e-6
mem_loss.append(loss.mean())
g=torch.autograd.grad(loss.mean(),x)[0]
d=-torch.matmul(B.H,g.unsqueeze(2))
k=0
#print(loss)
for i in range(steps):
    g_pre=g
    alpha=strong_wolfe(W,Y,batchsize,f, x, d, loss, g, c1=1e-4, c2=0.9, max_iter=10,device=device)
    update=alpha*(d.squeeze())
    x=x+update
    loss=f(W,Y,x)
    mem_loss.append(loss.mean())
    g=torch.autograd.grad(loss.mean(),x)[0]
    #print(torch.norm(g,dim=1).mean())
    if(sum(torch.norm(g,dim=1)<acc)>0):
        break
    d=-torch.matmul(H,g.unsqueeze(2))
    #print(B.H)
    input_vec=torch.cat((g,update),dim=1).unsqueeze(0)
    motify,state=LSTM_motify(input_vec,state)
    delta_H=motify.reshape((batchsize, DIM, DIM))
    H = H.clone().detach() + 1/2*(delta_H+delta_H.transpose(-2,-1))
    k+=1
    
print(k)    
plt.plot([i.cpu().detach().numpy() for i in mem_loss],label='LSTM_before_train')  
x = torch.zeros((batchsize,DIM),device=device,requires_grad=True)
steps=40
B=BFGS(batchsize,DIM,device)
mem_loss=[]
loss=f(W,Y,x)
acc=1e-6
mem_loss.append(loss.mean())
g=torch.autograd.grad(loss.mean(),x)[0]
d=-torch.matmul(B.H,g.unsqueeze(2))
k=0
#print(loss)
for i in range(steps):
    g_pre=g
    alpha=strong_wolfe(W,Y,batchsize,f, x, d, loss, g, c1=1e-4, c2=0.9, max_iter=10,device=device)
    update=alpha*(d.squeeze())
    x=x+update
    loss=f(W,Y,x)
    mem_loss.append(loss.mean())
    g=torch.autograd.grad(loss.mean(),x)[0]
    #print(torch.norm(g,dim=1).mean())
    if(sum(torch.norm(g,dim=1)<acc)>0):
        break
    d=-torch.matmul(B.H,g.unsqueeze(2))
    #print(B.H)
    B.H_BFDS_update(update,g-g_pre)
    k+=1
    
print(k)    
plt.plot([i.cpu().detach().numpy() for i in mem_loss],label='BFGS')  
plt.legend()

plt.show()
# Out:
# 40
# 40
